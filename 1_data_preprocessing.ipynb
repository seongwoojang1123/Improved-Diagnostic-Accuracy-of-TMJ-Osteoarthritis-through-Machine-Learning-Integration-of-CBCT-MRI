# %% [markdown]
# <a href="https://colab.research.google.com/github/seongwoojang1123/TMJ-osteoarthritis-diagnosis-/blob/main/1_data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '/content/drive/MyDrive/TMJ OA/20240819 CBCT MRI 데이터 정리 - 수정1.xlsx'

df = pd.read_excel(file_path, sheet_name='정리본')

# 'SEX (여성-F, 남성-M)' 컬럼명을 'SEX'로 변경
df.rename(columns={'SEX (여성-F, 남성-M)': 'SEX'}, inplace=True)
df['SEX'] = df['SEX'].map({'F': 0, 'M': 1})

# 빈문자열을 NaN으로 변경하기
df.replace("", np.nan, inplace=True)

columns = df.columns
print(len(columns))
print(columns)
df.head()
# Out:
# 9
# Index(['No.', 'Patient ID', 'NAME', 'SEX', 'AGE',
#        'CBCT_Rt OA (Osteoarthritis) (0=normal, 1=OA)',
#        'CBCT_Lt OA  (Osteoarthritis) (0=normal, 1=OA)',
#        'MRI_Rt OA (0=normal, 1=OA)', 'MRI_Lt OA (0=normal, 1=OA)'],
#       dtype='object')
#    No.  Patient ID NAME  SEX  AGE  \
# 0    1    20708532  사막동  0.0   68
# 1    2    20711690  이유진  0.0   23
# 2    3    20711556  이동규  1.0   26
# 3    4    20288547  지영선  1.0   66
# 4    5    20711599  배일웅  1.0   77
#
#    CBCT_Rt OA (Osteoarthritis) (0=normal, 1=OA)  \
# 0                                             1
# 1                                             0
# 2                                             1
# 3                                             0
# 4                                             1
#
#    CBCT_Lt OA  (Osteoarthritis) (0=normal, 1=OA)  MRI_Rt OA (0=normal, 1=OA)  \
# 0                                              1                         NaN
# 1                                              0                         NaN
# 2                                              1                         NaN
# 3                                              0                         NaN
# 4                                              1                         NaN
#
#    MRI_Lt OA (0=normal, 1=OA)
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN

# %%
df.describe()
# Out:
#                No.    Patient ID          SEX          AGE  \
# count  1219.000000  1.219000e+03  1218.000000  1219.000000
# mean    462.941756  2.060617e+07     0.297209    36.970468
# std     324.044771  3.750387e+05     0.457217    18.655043
# min       1.000000  1.069074e+07     0.000000    11.000000
# 25%     156.500000  2.059719e+07     0.000000    22.000000
# 50%     432.000000  2.067196e+07     0.000000    31.000000
# 75%     746.500000  2.068991e+07     1.000000    51.000000
# max    1064.000000  2.760186e+07     1.000000    90.000000
#
#        CBCT_Rt OA (Osteoarthritis) (0=normal, 1=OA)  \
# count                                   1219.000000
# mean                                       0.417555
# std                                        0.493358
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                        1.000000
#
#        CBCT_Lt OA  (Osteoarthritis) (0=normal, 1=OA)  \
# count                                    1219.000000
# mean                                        0.472518
# std                                         0.499449
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         1.000000
# max                                         1.000000
#
#        MRI_Rt OA (0=normal, 1=OA)  MRI_Lt OA (0=normal, 1=OA)
# count                  191.000000                  191.000000
# mean                     0.340314                    0.345550
# std                      0.475060                    0.476797
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      1.000000                    1.000000
# max                      1.000000                    1.000000

# %%
# CBCT와 MRI 이미지 갯수 확인

# CBCT 관련 컬럼들기
cbct_columns = ['CBCT_Rt OA (Osteoarthritis) (0=normal, 1=OA)', 'CBCT_Lt OA  (Osteoarthritis) (0=normal, 1=OA)']

# MRI 관련 컬럼들
mri_columns = ['MRI_Rt OA (0=normal, 1=OA)', 'MRI_Lt OA (0=normal, 1=OA)']

# CBCT 값 개수 확인 (0과 1의 개수)
cbct_counts = df[cbct_columns].apply(pd.Series.value_counts)
print("CBCT 데이터 개수:")
print(cbct_counts)

# MRI 값 개수 확인 (0과 1의 개수)
mri_counts = df[mri_columns].apply(pd.Series.value_counts)
print("\nMRI 데이터 개수:")
print(mri_counts)
# Out:
# CBCT 데이터 개수:
#    CBCT_Rt OA (Osteoarthritis) (0=normal, 1=OA)  \
# 0                                           710
# 1                                           509
#
#    CBCT_Lt OA  (Osteoarthritis) (0=normal, 1=OA)
# 0                                            643
# 1                                            576
#
# MRI 데이터 개수:
#      MRI_Rt OA (0=normal, 1=OA)  MRI_Lt OA (0=normal, 1=OA)
# 0.0                         126                         125
# 1.0                          65                          66

# %%
# 데이터 저장
data = pd.DataFrame(df)
print(f'data.shape : {data.shape}')
data.to_csv('/content/drive/MyDrive/241023_TMJ OA data.csv', index=False, encoding = 'utf-8')
